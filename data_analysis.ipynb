# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#                          time  temp  hum  dist
# 0  2023-01-30 18:51:49.290512    22   60    16
# 1  2023-01-30 18:51:52.900522    22   68     7
# 2  2023-01-30 18:51:56.465147    23   73    20
# 3  2023-01-30 18:51:59.851707    23   76    30
# 4  2023-01-30 18:52:04.150642    23   78     7

# %%
df = data.copy()
df['time'] = pd.to_datetime(df['time'])

# set min value to seconds
df['time'] = df['time'].dt.floor('s')

# %%
df
# Out:
#                   time  temp  hum  dist
# 0  2023-01-30 18:51:49    22   60    16
# 1  2023-01-30 18:51:52    22   68     7
# 2  2023-01-30 18:51:56    23   73    20
# 3  2023-01-30 18:51:59    23   76    30
# 4  2023-01-30 18:52:04    23   78     7
# 5  2023-01-30 18:52:07    23   78    13
# 6  2023-01-30 18:52:11    23   67    11
# 7  2023-01-30 18:52:14    23   66    16
# 8  2023-01-30 18:52:19    23   44    23
# 9  2023-01-30 18:52:24    23   56   121
# 10 2023-01-30 18:52:28    23   68    29

# %%
plt.figure(figsize=(10, 7))
plt.scatter(x = df['time'], y = df['temp'])
plt.plot(df['time'], df['temp'])
plt.title('Temperature over time')
plt.xlabel('Time')
plt.ylabel('Temperature in °C')
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.scatter(x = df['time'], y = df['hum'])
plt.plot(df['time'], df['hum'])
plt.title('Relative humidity over time')
plt.xlabel('Time')
plt.ylabel('Relative humidity in %')
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.scatter(x = df['time'], y = df['dist'])
plt.plot(df['time'], df['dist'])
plt.title('Distance over time')
plt.xlabel('Time')
plt.ylabel('Distance in cm')
plt.show()
